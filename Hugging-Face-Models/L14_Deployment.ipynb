# %% [markdown]
# # (Optional) Lesson 14: Deploy ML Models on 🤗 Hub using Gradio

# %% [markdown]
# - Welcome to the last lesson - ML deployment using 🤗 Hub and Gradio libraries.
# - This lesson is optional.  You can watch the video first to see a walkthrough of how to deploy to Hugging Face Spaces.
# - If you would like to follow along or deploy to Hugging Face Spaces later, you can do so by creating a free account on https://huggingface.co/
# - You are not required to create an account to complete this lesson, as this lesson contains screenshots and instructions for how to deploy, but does not have any code that requires you to have a Hugging Face account.

# %% [markdown]
# - In the classroom, the libraries are already installed for you.
# - If you would like to run this code on your own machine, you can install the following:
#
# ```
#     !pip install transformers
#     !pip install gradio
#     !pip install gradio_client
# ```

# %% [markdown]
# - Note that if you run into issues when making an API call to your own space, you can try to upgrade your version of gradio_client:
#
# ```
# pip install -U gradio_client
# ```

# %% [markdown]
# - Here is some code that suppresses warning messages.

# %%
from transformers.utils import logging
logging.set_verbosity_error()

import warnings
warnings.filterwarnings("ignore", 
                        message="Using the model-agnostic default `max_length`")

# %% [markdown]
# ## 🤗 Spaces

# %% [markdown]
# - You can create an account on hugging face from [here](https://huggingface.co), to follow the instructions provided in the video.

# %% [markdown]
# ### App Demo: Image Captioning

# %% [markdown]
# - Load the model and create an app interface using Gradio to perform Image Captioning.
#
# ### Troubleshooting Tip
# - Note, in the classroom, you may see the code for creating the Gradio app run indefinitely.
#   - This is specific to this classroom environment when it's serving many learners at once, and you won't wouldn't experience this issue if you run this code on your own machine.
# - To fix this, please restart the kernel (Menu Kernel->Restart Kernel) and re-run the code in the lab from the beginning of the lesson.

# %%
import os
import gradio as gr
from transformers import pipeline

# %%
pipe = pipeline("image-to-text",
                model="./models/Salesforce/blip-image-captioning-base")

# %%
def launch(input):
    out = pipe(input)
    return out[0]['generated_text']

# %%
iface = gr.Interface(launch,
                     inputs=gr.Image(type='pil'),
                     outputs="text")
# Out:
# IMPORTANT: You are using gradio version 4.16.0, however version 4.44.1 is available, please upgrade.
# --------

# %%
iface.launch(share=True, 
             server_port=int(os.environ['PORT1']))
# Out:
# Running on local URL:  https://0.0.0.0:8000
# Running on public URL: https://5b08b13d37b0c06428.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://5b08b13d37b0c06428.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# - Close the demo port.

# %%
iface.close()
# Out:
# Closing server running on port: 8000

# %% [markdown]
# ### Close the app
# - Please remember to call `.close()` on the Gradio app before continuing.

# %% [markdown]
# ### Deploying to Hugging Face Spaces
#
# - Go to [https://huggingface.co/spaces](https://huggingface.co/spaces)![](./images_app/create_new_space_00.png)
#
#
# - Click the button "create new space".

# %% [markdown]
# ![](./images_app/create_new_space_01.png)
#
# - Give the space a name, such as "blip-image-captioning".
# - Choose a license, such as Apache 2.0
# - For "Select the Space SDK", click "Gradio".
# - For Hardware, choose the default free option: "CPU Basic"

# %% [markdown]
# ![](./images_app/create_new_space_02.png)
# - Leave it as "public"
# - Click "create space".

# %% [markdown]
# ![](./images_app/get_started_01.png)
#
# - You will see a new page with instructions for how to get started by cloning and updating a GitHub repo.
# - You can also add the required files directly in the web browser if you'd like to get a small app running quickly.  Click on "Files" at the top.

# %% [markdown]
# ![](./images_app/files_01.png)
#
# - Click on "+ Add file"->"Create new File".

# %% [markdown]
# ### Add requirements.txt

# %% [markdown]
# ![](./images_app/requirements_01.png)

# %% [markdown]
# - Add a file called requirements.txt.
# - Paste in the following:
#
# ```
# transformers
# torch
# gradio
# ```
#
# - Leave "Commit Directly to the main branch" selected.
# - Click "commit new file to main".

# %% [markdown]
# ### Add app.py

# %% [markdown]
# ![](./images_app/app_01.png)

# %% [markdown]
# - In the textbox "Name Your File", type "app.py"
# - In the textbox for your code, paste in the code that you ran above, or copy this block below:
#
#
#
# ```Python
# import gradio as gr
# from transformers import pipeline
#
# pipe = pipeline("image-to-text",
#                 model="Salesforce/blip-image-captioning-base")
#
#
# def launch(input):
#     out = pipe(input)
#     return out[0]['generated_text']
#
# iface = gr.Interface(launch,
#                      inputs=gr.Image(type='pil'),
#                      outputs="text")
#
# iface.launch()
# ```
# - Notice that `iface.launch()` does not have `share=True`

# %% [markdown]
# ![](./images_app/app_02.png)

# %% [markdown]
# - Leave "Commit Directly to the main branch" selected.
# - Click "Commit new file to main".

# %% [markdown]
# ### View the app
# ![](./images_app/app_tab.png)

# %% [markdown]
# - You will see that the app is still "Building" for a few minutes.
# - You can click on the "App" menu to the left of the "Files" menu to see the console as the space is being built.
# ![](app_tab.png)

# %% [markdown]
# ![](./images_app/app_tab_03.png)

# %% [markdown]
# - When the build is done, you'll see your app!
# - At the bottom, you can click "Use via API" to see sample code that you can use to use your model with an API call.

# %% [markdown]
# ![](./images_app/api_01.png)

# %% [markdown]
# - You can run the pip install if you haven't already done so.
# - In the classroom, gradio_client should already be installed for you.
# - Copy the sample code, which will look something like this:
#
# ```Python
# from gradio_client import Client
#
# client = Client("eddyS/blip-image-captioning-2")
# result = client.predict(
# 		"https://raw.githubusercontent.com/gradio-app/gradio/main/test/test_files/bus.png",	# filepath  in 'input' Image component
# 		api_name="/predict"
# )
# print(result)
# ```

# %% [markdown]
# - Note, you can replace the string within `client.predict()` with a string that points to a local file.
# - In the classroom, there are two image files that you can use.
#   - "kittens.jpg"
#   - "huggingface_friends.jpg"
#   - Feel free to upload your own to the file directory.
#
# So your code may look like this:
# ```Python
# from gradio_client import Client
#
# client = Client("eddyS/blip-image-captioning-2")
# result = client.predict(
# 		"kittens.jpg",
# 		api_name="/predict"
# )
# print(result)
# ```

# %%
pip install gradio==4.35.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gradio==4.35.0
#   Downloading gradio-4.35.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.9/site-packages (from gradio==4.35.0) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.9/site-packages (from gradio==4.35.0) (5.2.0)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.9/site-packages (from gradio==4.35.0) (0.109.2)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.9/site-packages (from gradio==4.35.0) (0.3.1)
# Collecting gradio-client==1.0.1 (from gradio==4.35.0)
#   Downloading gradio_client-1.0.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.9/site-packages (from gradio==4.35.0) (0.26.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /usr/local/lib/python3.9/site-packages (from gradio==4.35.0) (0.20.3)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.9/site-packages (from gradio==4.35.0) (6.1.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.9/site-packages (from gradio==4.35.0) (3.1.3)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.9/site-packages (from gradio==4.35.0) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.9/site-packages (from gradio==4.35.0) (3.8.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.9/site-packages (from gradio==4.35.0) (1.26.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.9/site-packages (from gradio==4.35.0) (3.9.13)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/site-packages (from gradio==4.35.0) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.9/site-packages (from gradio==4.35.0) (2.2.0)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.9/site-packages (from gradio==4.35.0) (10.2.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.9/site-packages (from gradio==4.35.0) (2.6.0)
# Requirement already satisfied: pydub in /usr/local/lib/python3.9/site-packages (from gradio==4.35.0) (0.25.1)
# Collecting python-multipart>=0.0.9 (from gradio==4.35.0)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.9/site-packages (from gradio==4.35.0) (6.0.1)
# Collecting ruff>=0.2.2 (from gradio==4.35.0)
#   Downloading ruff-0.14.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.9/site-packages (from gradio==4.35.0) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /usr/local/lib/python3.9/site-packages (from gradio==4.35.0) (0.12.0)
# Collecting typer<1.0,>=0.12 (from gradio==4.35.0)
#   Downloading typer-0.20.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.9/site-packages (from gradio==4.35.0) (4.10.0)
# Requirement already satisfied: urllib3~=2.0 in /usr/local/lib/python3.9/site-packages (from gradio==4.35.0) (2.2.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.9/site-packages (from gradio==4.35.0) (0.27.0.post1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.9/site-packages (from gradio-client==1.0.1->gradio==4.35.0) (2023.10.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /usr/local/lib/python3.9/site-packages (from gradio-client==1.0.1->gradio==4.35.0) (11.0.3)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.9/site-packages (from altair<6.0,>=4.2.0->gradio==4.35.0) (4.21.1)
# Requirement already satisfied: toolz in /usr/local/lib/python3.9/site-packages (from altair<6.0,>=4.2.0->gradio==4.35.0) (0.12.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.9/site-packages (from httpx>=0.24.1->gradio==4.35.0) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/site-packages (from httpx>=0.24.1->gradio==4.35.0) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.9/site-packages (from httpx>=0.24.1->gradio==4.35.0) (1.0.2)
# Requirement already satisfied: idna in /usr/local/lib/python3.9/site-packages (from httpx>=0.24.1->gradio==4.35.0) (3.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.9/site-packages (from httpx>=0.24.1->gradio==4.35.0) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio==4.35.0) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/site-packages (from huggingface-hub>=0.19.3->gradio==4.35.0) (3.13.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/site-packages (from huggingface-hub>=0.19.3->gradio==4.35.0) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.9/site-packages (from huggingface-hub>=0.19.3->gradio==4.35.0) (4.66.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/site-packages (from importlib-resources<7.0,>=1.3->gradio==4.35.0) (3.18.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/site-packages (from matplotlib~=3.0->gradio==4.35.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/site-packages (from matplotlib~=3.0->gradio==4.35.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/site-packages (from matplotlib~=3.0->gradio==4.35.0) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.9/site-packages (from matplotlib~=3.0->gradio==4.35.0) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/site-packages (from matplotlib~=3.0->gradio==4.35.0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/site-packages (from matplotlib~=3.0->gradio==4.35.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/site-packages (from pandas<3.0,>=1.0->gradio==4.35.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.9/site-packages (from pandas<3.0,>=1.0->gradio==4.35.0) (2023.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.9/site-packages (from pydantic>=2.0->gradio==4.35.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.1 in /usr/local/lib/python3.9/site-packages (from pydantic>=2.0->gradio==4.35.0) (2.16.1)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.9/site-packages (from typer<1.0,>=0.12->gradio==4.35.0) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.9/site-packages (from typer<1.0,>=0.12->gradio==4.35.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.9/site-packages (from typer<1.0,>=0.12->gradio==4.35.0) (13.7.0)
# Requirement already satisfied: starlette<0.37.0,>=0.36.3 in /usr/local/lib/python3.9/site-packages (from fastapi->gradio==4.35.0) (0.36.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.35.0) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.35.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.35.0) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.35.0) (0.18.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio==4.35.0) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.9/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==4.35.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==4.35.0) (2.17.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.9/site-packages (from anyio->httpx>=0.24.1->gradio==4.35.0) (1.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.9/site-packages (from requests->huggingface-hub>=0.19.3->gradio==4.35.0) (3.3.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio==4.35.0) (0.1.2)
# Downloading gradio-4.35.0-py3-none-any.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 30.6 MB/s eta 0:00:0000:010:01m
# Downloading gradio_client-1.0.1-py3-none-any.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.1/318.1 kB 71.1 MB/s eta 0:00:00
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading ruff-0.14.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 129.3 MB/s eta 0:00:0000:010:01
# Downloading typer-0.20.0-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 12.2 MB/s eta 0:00:00
# Installing collected packages: ruff, python-multipart, typer, gradio-client, gradio
#   WARNING: The script typer is installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Attempting uninstall: gradio-client
#     Found existing installation: gradio_client 1.3.0
#     Uninstalling gradio_client-1.3.0:
#       Successfully uninstalled gradio_client-1.3.0
#   WARNING: The scripts gradio and upload_theme are installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed gradio-4.35.0 gradio-client-1.0.1 python-multipart-0.0.20 ruff-0.14.4 typer-0.20.0
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import gradio
print(gradio.__version__)
# Out:
# 4.35.0

# %%
import gradio_client
print(gradio_client.__version__)
# Out:
# 1.3.0

# %%
response = httpx.get(
    "https://xinkaichen-blip-image-captioning.hf.space/info",
    follow_redirects=True
)
print("Status:", response.status_code)
print("Content-Type:", response.headers.get("content-type"))
# Out:
# Status: 200
# Content-Type: text/html

# %%
from gradio_client import Client, handle_file

client = Client("xinkaichen/blip-image-captioning")
result = client.predict(
    input=handle_file('https://raw.githubusercontent.com/gradio-app/gradio/main/test/test_files/bus.png'),
    api_name="/predict"
)
print(result)

# %% [markdown]
# - Inspect the information in the API.
#
# ```Python
# client.view_api()
# ```
# - The output may look like this:
#
#
# ```
# Client.predict() Usage Info
# ---------------------------
# Named API endpoints: 1
#
#  - predict(input, api_name="/predict") -> output
#     Parameters:
#      - [Image] input: filepath
#     Returns:
#      - [Textbox] output: str
#
# ```

# %% [markdown]
# ### (Optional) Access to your private space as an API.
#
# You can make your space private, so that it can be accessed with an access token.
#
# To make the space private click on the "Settings" menu at the top.  Scroll down until you see "Change space visibility" and click the "Make private" button.
#
# ![](./images_app/private_01.png)

# %% [markdown]
# ### Get an access token
# - To get an access token, go to your profile (click on your profile icon).
# - On your profile page, click the "Settings" button on the left.
#
# ![](./images_app/profile_01.png)

# %% [markdown]
# - In your profile settings, on the left side menu, click "Access Tokens".
# - Click "New token".

# %% [markdown]
# ![](./images_app/access_tokens_01.png)

# %% [markdown]
# - In the pop-up, give a description of what the token is for.
# - You can leave it as "read" (the other option is "write").
# - Click "create new token".
#
# ![](./images_app/new_token_01.png)

# %% [markdown]
# - You can copy the access token.

# %% [markdown]
# ![](./images_app/access_tokens_02.png)

# %% [markdown]
# You can modify the API call to include your access token.
#
# ```Python
# from gradio_client import Client
#
# client = Client("eddyS/blip-image-captioning-2",
#                 hf_token=hf_access_token
#                )
# result = client.predict(
# 		"kittens.jpg",
# 		api_name="/predict"
# )
# print(result)
# # client = Client("abidlabs/whisper-large-v2",
# )
# ```

# %% [markdown]
# ### Saving your access token securely
# - It's recommended that you not hard code the access token.
#
# ```Python
# HF_TOKEN="abc1234" # not recommended
# ```
#
# - You can save your access token to a file ".env"
#
# ```
# HF_ACCESS_TOKEN="abc123"
# ```
#
# Then access that environment variable with the `dotenv` library
#
# ```Python
# # !pip install python-dotenv # install library
# from dotenv import load_dotenv, find_dotenv
# import os
# _ = load_dotenv(find_dotenv())
# hf_access_token = os.getenv("HF_ACCESS_TOKEN")
# ```

# %% [markdown]
# ### GPU Zero Space
# - [ZeroGPU Explorers](https://huggingface.co/zero-gpu-explorers): A place to spin free GPUs on demand for your spaces.

# %% [markdown]
# ![](./images_app/gpu_01.png)

# %% [markdown]
# - You can click "request to join this org".
# - It may take a few days/weeks for this to be approved.
